# %% [markdown]
# Heart disease is one of the biggest causes of morbidity and mortality among the population of the world.
# The amount of data in the healthcare industry is huge. Data mining turns the large collection of raw healthcare data into information that can help to make informed decisions and predictions.
# Tt is difficult to track and predict heart disease because of several contributory risk factors such as diabetes, high blood pressure, high cholesterol, bad eating habits and many more.

# %% [markdown]
# The Data
#
# We shall be using the Heart Disease Cleveland UCI Dataset.
#
# The columns indicate-
#
# 1. age-   age in years
# 2. sex-   sex (1: male; 0: female)
# 3. cp-   pain type (0: typical angina 1: atypical angina 2: non-anginal pain 3: asymptomatic)
# 4. trestbps-   resting blood pressure
# 5. chol-   cholestoral in mg/dl
# 6. fbs-   blood sugar > 120 mg/dl (1: true; 0: false)
# 7. restecg-   electrocardiographic results (0: normal 1: having ST-T wave abnormality
# (T wave inversions and/or ST elevation or depression of > 0.05 mV) 2: showing probable or definite left ventricular hypertrophy by Estes' criteria)
#
# 8. thalach-   maximum heart rate achieved
# 9. exang-   exercise induced angina (1: yes; 0: no)
# 10. oldpeak-   ST depression induced by exercise relative to rest
# 11. slope-   the slope of the peak exercise ST segment (0: upsloping 1: flat 2: downsloping)
# 12. ca-   number of major vessels (0-3) colored by flourosopy
# 13. thal-   thal (0: normal; 1: fixed defect; 2: reversable defect)
# 14. target-   disease condition (0: No disease; 1: disease)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('heart.csv')

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
# age         303 non-null int64
# sex         303 non-null int64
# cp          303 non-null int64
# trestbps    303 non-null int64
# chol        303 non-null int64
# fbs         303 non-null int64
# restecg     303 non-null int64
# thalach     303 non-null int64
# exang       303 non-null int64
# oldpeak     303 non-null float64
# slope       303 non-null int64
# ca          303 non-null int64
# thal        303 non-null int64
# target      303 non-null int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
#Age of people taken in consideration

# %%
sns.distplot(df['age'],color="#081aa1")

# %%
sns.distplot(df['age'],color="#081aa1",kde=False)

# %%
sns.distplot(df["age"],bins=20,color="#081aa1",kde=False)

# %%
plt.xlim(40,80)
sns.distplot(df["age"],color="#081aa1",kde=False)

# %%
#relation between various data

# %%
sns.distplot(df['chol'],color="#081aa1",kde=False)

# %%
plt.xlabel("Age(In Years)")
plt.ylabel("Cholestrol Levels(mg/dl)")

plt.scatter(df["age"],df["chol"],marker=".")

# %%
plt.xlabel("Age(In Years)")
plt.ylabel("Resting Blood Pressure(Systolic)")

plt.scatter(df["age"],df["trestbps"],marker=".")

# %%
plt.xlabel("Age(In Years)")
plt.ylabel("Maximum Heart Beat Rate")

plt.scatter(df["age"],df["thalach"],marker=".")

# %%
#(1: male; 0: female)

plt.figure(figsize=(14, 5))
sns.countplot(x='sex',data=df)

# %%
#(0: No disease; 1: disease)

plt.figure(figsize=(14, 5))
sns.countplot(x='target',data=df)

# %%
#  (0: typical angina 1: atypical angina 2: non-anginal pain 3: asymptomatic)

plt.figure(figsize=(14, 5))
sns.countplot(x='cp',data=df)

# %%
#  cp- (0: typical angina 1: atypical angina 2: non-anginal pain 3: asymptomatic)
#  (1: male; 0: female)

plt.figure(figsize=(14, 5))
sns.countplot(x='cp',data=df,hue="sex")

# %%
#  cp- (0: typical angina 1: atypical angina 2: non-anginal pain 3: asymptomatic)
#  fbs- blood sugar > 120 mg/dl (1: true; 0: false)

plt.figure(figsize=(14, 5))
sns.countplot(x='cp',data=df,hue="fbs", palette='cool')

# %%
#   target- disease condition (0: No disease; 1: disease)
#   (1: male; 0: female)

plt.figure(figsize=(14, 5))
sns.countplot(x='target',data=df,hue="sex",palette="winter" )

# %%
#   target- disease condition (0: No disease; 1: disease)
#   exang- exercise induced angina (1: yes; 0: no)

plt.figure(figsize=(14, 5))
sns.countplot(x='target',data=df,hue="exang",palette="winter" )

# %%
#   cp- pain type (0: typical angina 1: atypical angina 2: non-anginal pain 3: asymptomatic)
#   target- disease condition (0: No disease; 1: disease)

plt.figure(figsize=(14, 5))
sns.countplot(x='target',data=df,hue="cp" )

# %%
#   restecg- electrocardiographic results (0: normal 1: having ST-T wave abnormality
#   2: showing probable or definite left ventricular hypertrophy 
#   target- disease condition (0: No disease; 1: disease)

plt.figure(figsize=(14, 5))
sns.countplot(x='target',data=df,hue="restecg" )

# %%
#chol- cholestoral in mg/dl
#trestbps- resting blood pressure (mm of Hg)
#sex- sex (1: male; 0: female)

plt.figure(figsize=(14, 5))
sns.scatterplot(x='chol',y='trestbps',data=df,hue='sex')

# %%
#chol- cholestoral in mg/dl
#trestbps- resting blood pressure (mm of Hg)
#sex- sex (1: male; 0: female)

plt.figure(figsize=(14, 5))
sns.scatterplot(x='chol',y='trestbps',data=df,hue='sex',size='age')

# %%
#chol- cholestoral in mg/dl
#trestbps- resting blood pressure (mm of Hg)
#cp- pain type (0: typical angina 1: atypical angina 2: non-anginal pain 3: asymptomatic)


plt.figure(figsize=(14, 5))
sns.scatterplot(x='chol',y='trestbps',data=df,hue='cp',palette="plasma")

# %%
#chol- cholestoral in mg/dl
#trestbps- resting blood pressure (mm of Hg)
#thal- thal (0: normal; 1: fixed defect; 2: reversable defect)


plt.figure(figsize=(14, 5))
sns.scatterplot(x='chol',y='trestbps',data=df,hue='thal',palette="tab10")

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
#Regression Plot between maximum heart rate achieved and resting blood pressure

plt.figure(figsize=(14, 5))
sns.regplot("trestbps","thalach",data=df)

# %%
#Regression Plot between cholestoral and resting blood pressure

plt.figure(figsize=(14, 5))
sns.regplot("trestbps","chol",data=df)

# %%
#Regression Plot between cholestoral and maximum heart rate achieved

plt.figure(figsize=(14, 5))
sns.regplot("thalach","chol",data=df)
